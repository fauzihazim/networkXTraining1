# %% [markdown]
# <a href="https://colab.research.google.com/github/fauzihazim/networkXTraining1/blob/main/NetworkX_Training_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
G_symmetric = nx.Graph()
G_symmetric.add_edge(1,2)
G_symmetric.add_edge(1,3)
G_symmetric.add_edge(1,4)
G_symmetric.add_edge(1,5)
G_symmetric.add_edge(1,6)
G_symmetric.add_edge(1,7)
G_symmetric.add_edge(1,8)
G_symmetric.add_edge(5,6)
G_symmetric.add_edge(5,8)
G_symmetric.add_edge(6,7)
nx.draw_networkx(G_symmetric)

# %%
G_symmetric.remove_node(4)
G_symmetric.remove_edge(1, 8)
nx.draw_networkx(G_symmetric)
